# %%
import numpy as np
import sqlite3
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
def create_connection(path):
    connection = None
    try: 
        connection = sqlite3.connet(path)
        print("Connected to SQL database:D")
    except Error as e:
        print(f"The error '{e}' occurued")
        
    return connection

# %%
file_name = "Case_Data.xlsx"
df = pd.read_excel(io=file_name)

# %%
df.head()
# Out:
#    Id   Modell Selger           Kjøper     Kjøpertype Drivstoff      Type bil  \
# 0   1  Phantum    Are              Per   Barnefamilie        El           SUV
# 1   2     Fiet    Are      Ole og Kari    Kjærestepar        El      To-seter
# 2   3     Fiet  Chris              Eva  Enslig kvinne        El      To-seter
# 3   4  Phantum   Dina             Carl    Enslig mann        El           SUV
# 4   5     Bius  Berit  Ina og Torstein   Barnefamilie    Bensin  Stasjonsvogn
#
#    Innkjøpspris  Utsalgspris  Avgifter       Dato
# 0        550000       600000         0 2020-01-02
# 1        180000       200000         0 2020-01-11
# 2        180000       200000         0 2020-01-11
# 3        550000       600000         0 2020-01-24
# 4        200000       300000     50000 2020-01-25

# %%
df.keys()
# Out:
# Index(['Id', 'Modell', 'Selger', 'Kjøper', 'Kjøpertype', 'Drivstoff',
#        'Type bil', 'Innkjøpspris', 'Utsalgspris', 'Avgifter', 'Dato'],
#       dtype='object')

# %%
print(df['Modell'].value_counts())
print(df['Selger'].value_counts())
print(df['Kjøpertype'].value_counts())
print(df['Drivstoff'].value_counts())
print(df['Innkjøpspris'].value_counts())
print(df['Utsalgspris'].value_counts())
print(df['Avgifter'].value_counts())
# Out:
# Phantum    15
# Modus      14
# Bius       13
# Fiet       10
# Name: Modell, dtype: int64
# Dina     15
# Are      14
# Berit    12
# Chris    11
# Name: Selger, dtype: int64
# Barnefamilie     17
# Kjærestepar      15
# Enslig mann      11
# Enslig kvinne     9
# Name: Kjøpertype, dtype: int64
# El        26
# Diesel    14
# Bensin    12
# Name: Drivstoff, dtype: int64
# 550000    15
# 150000    14
# 200000    13
# 180000    10
# Name: Innkjøpspris, dtype: int64
# 300000    27
# 600000    15
# 200000    10
# Name: Utsalgspris, dtype: int64
# 50000    27
# 0        25
# Name: Avgifter, dtype: int64

# %%
df['Fortjeneste'] = df['Utsalgspris'] 

for car_num in range(df.shape[0]):
      df['Fortjeneste'][car_num] -= ( df['Innkjøpspris'][car_num] + df['Avgifter'][car_num])
# Out:
# C:\Users\karolmny\AppData\Local\Temp\ipykernel_12616\1176200083.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fortjeneste'][car_num] -= ( df['Innkjøpspris'][car_num] + df['Avgifter'][car_num])

# %%
df.describe()
# Out:
#               Id   Innkjøpspris    Utsalgspris      Avgifter    Fortjeneste
# count  52.000000      52.000000      52.000000     52.000000      52.000000
# mean   26.500000  283653.846154  367307.692308  25961.538462   57692.307692
# std    15.154757  172217.701331  154312.077280  25225.229775   28326.900166
# min     1.000000  150000.000000  200000.000000      0.000000   20000.000000
# 25%    13.750000  150000.000000  300000.000000      0.000000   50000.000000
# 50%    26.500000  200000.000000  300000.000000  50000.000000   50000.000000
# 75%    39.250000  550000.000000  600000.000000  50000.000000  100000.000000
# max    52.000000  550000.000000  600000.000000  50000.000000  100000.000000

# %%
df['Modell'].hist(by=df['Selger'])
# Out:
# array([[<AxesSubplot:title={'center':'Are'}>,
#         <AxesSubplot:title={'center':'Berit'}>],
#        [<AxesSubplot:title={'center':'Chris'}>,
#         <AxesSubplot:title={'center':'Dina'}>]], dtype=object)

# %%
plt.hist(df['Drivstoff'], label="Salg av drivstoff")
df['Kjøpertype'].hist(by=df['Drivstoff'])
df['Drivstoff'].hist(by=df['Kjøpertype'])






#df['Kjøpertype'].hist(by=df['Drivstoff'])
# Out:
# array([[<AxesSubplot:title={'center':'Barnefamilie'}>,
#         <AxesSubplot:title={'center':'Enslig kvinne'}>],
#        [<AxesSubplot:title={'center':'Enslig mann'}>,
#         <AxesSubplot:title={'center':'Kjærestepar'}>]], dtype=object)

# %%
df['Fortjeneste'].hist(by=df['Drivstoff'])
# Out:
# array([[<AxesSubplot:title={'center':'Bensin'}>,
#         <AxesSubplot:title={'center':'Diesel'}>],
#        [<AxesSubplot:title={'center':'El'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#fiet = df.loc[df['Modell'] == 'Fiet']
#print(fiet)
#fiet.plot.hist()

# %%
#df.plot.bar(stacked=True)
#df.loc[['Modell'],['Drivstoff']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12616\1520221043.py in <module>
#       1 #df.plot.bar(stacked=True)
# ----> 2 df.loc[['Modell'],['Drivstoff']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1145         # ugly hack for GH #836
#    1146         if self._multi_take_opportunity(tup):
# -> 1147             return self._multi_take(tup)
#    1148
#    1149         return self._getitem_tuple_same_dim(tup)
#
# ...
